# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
msft = yf.Ticker("MSFT")

msft.info['SandP52WeekChange']
# Out:
# 0.14113986

# %%
print?

# %%
df = msft.history(period='12mo')

# %%
msft_open = df['Open']
msft_close = df['Close']

plt.plot(msft_open, color='green');
plt.plot(msft_close, color='red');
plt.plot((msft_open+msft_close)/2, color='grey');

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1694808004,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 330.22,
#  'chartPreviousClose': 245.38,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'end': 1694784600,
#    'start': 1694764800,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'end': 1694808000,
#    'start': 1694784600,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'end': 1694822400,
#    'start': 1694808000,
#    'gmtoffset': -14400}},
#  'dataGranularity': '1d',
#  'range': '12mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
msft.isin
# Out:
# '-'

# %%
msft.sustainability()
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 msft.sustainability()
#
# File ~\anaconda3\envs\sh23\Lib\site-packages\yfinance\ticker.py:234, in Ticker.sustainability(self)
#     232 @property
#     233 def sustainability(self) -> _pd.DataFrame:
# --> 234     return self.get_sustainability()
#
# File ~\anaconda3\envs\sh23\Lib\site-packages\yfinance\base.py:1693, in TickerBase.get_sustainability(self, proxy, as_dict)
#    1691 def get_sustainability(self, proxy=None, as_dict=False):
#    1692     self._quote.proxy = proxy
# -> 1693     data = self._quote.sustainability
#    1694     if as_dict:
#    1695         return data.to_dict()
#
# File ~\anaconda3\envs\sh23\Lib\site-packages\yfinance\scrapers\quote.py:579, in Quote.sustainability(self)
#     576 @property
#     577 def sustainability(self) -> pd.DataFrame:
#     578     if self._sustainability is None:
# --> 579         raise YFNotImplementedError('sustainability')
#     580     return self._sustainability
#
# YFNotImplementedError: Have not implemented fetching 'sustainability' from Yahoo API

# %%
import requests

def handler(pd: "pipedream"):
  headers = {"X-RapidAPI-Key": f'{{{{custom_fields["X-RapidAPI-Key"]}}}}', "X-RapidAPI-Host": 'apidojo-yahoo-finance-v1.p.rapidapi.com'}
  r = requests.get('https://apidojo-yahoo-finance-v1.p.rapidapi.com/auto-complete', params={"q": 'tesla', "region": 'US'}, headers=headers)
  # Export the data for use in future steps
  return r.json()

# %%
handler()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 handler()
#
# TypeError: handler() missing 1 required positional argument: 'pd'

# %%
# Out:
#   Cell In[44], line 1
#     msft.
#          ^
# SyntaxError: invalid syntax

# %%
import yesg

# %%
df = yesg.get_historic_esg('MSFT')
df
# Out:
#             Total-Score  E-Score  S-Score  G-Score
# Date
# 2014-09-01        66.00    78.00    59.00    63.00
# 2014-10-01        66.00    78.00    59.00    63.00
# 2014-11-01        66.00    78.00    59.00    63.00
# 2014-12-01        66.00    78.00    59.00    63.00
# 2015-01-01        66.00    78.00    59.00    63.00
# ...                 ...      ...      ...      ...
# 2022-04-01          NaN      NaN      NaN      NaN
# 2022-05-01        13.75     0.46     8.06     5.23
# 2022-06-01          NaN      NaN      NaN      NaN
# 2022-07-01          NaN      NaN      NaN      NaN
# 2022-08-01        15.24     1.53     8.39     5.33
#
# [96 rows x 4 columns]

# %%
plt.plot(df['Total-Score']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.plot(df['Total-Score'])
#
# NameError: name 'plt' is not defined
